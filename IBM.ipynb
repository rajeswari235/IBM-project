# %%
import pandas as pd
x=pd.read_csv("/home/rgukt/Desktop/Iris.csv")
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 145  146            6.7           3.0            5.2           2.3  \
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
x.shape
# Out:
# (150, 6)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
x.describe(include="all").T
# Out:
#                count unique          top freq      mean        std  min
# Id             150.0    NaN          NaN  NaN      75.5  43.445368  1.0  \
# SepalLengthCm  150.0    NaN          NaN  NaN  5.843333   0.828066  4.3
# SepalWidthCm   150.0    NaN          NaN  NaN     3.054   0.433594  2.0
# PetalLengthCm  150.0    NaN          NaN  NaN  3.758667    1.76442  1.0
# PetalWidthCm   150.0    NaN          NaN  NaN  1.198667   0.763161  0.1
# Species          150      3  Iris-setosa   50       NaN        NaN  NaN
#
#                  25%   50%     75%    max
# Id             38.25  75.5  112.75  150.0
# SepalLengthCm    5.1   5.8     6.4    7.9
# SepalWidthCm     2.8   3.0     3.3    4.4
# PetalLengthCm    1.6  4.35     5.1    6.9
# PetalWidthCm     0.3   1.3     1.8    2.5
# Species          NaN   NaN     NaN    NaN

# %%
x.describe(include="object").T
# Out:
#         count unique          top freq
# Species   150      3  Iris-setosa   50

# %%
x.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
x.duplicated().sum()
# Out:
# 0

# %%
x.drop_duplicates()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
x.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
x.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
x.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
x.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
x.drop(columns="Id",inplace=True)

# %%
x.head(1)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
import numpy as np
sales_data = {"Person": ["tarak","dev", "hari","karim", "vanitha", "prasanthi", "mouli", "dev"],
            "Company" : [ "CompA","CompA", "CompA", "CompB", "CompB", "CompC", "CompC", "CompA"],
             "Sales"  : [   250  ,  250  ,   150  ,   340  ,   np.nan ,   243  ,   350  ,   250],
             "Age"    : [    23  ,  24   ,   25   ,   250  ,  np.nan,   27   ,    24  ,    24] }
df = pd.DataFrame(sales_data)
df
# Out:
#       Person Company  Sales    Age
# 0      tarak   CompA  250.0   23.0
# 1        dev   CompA  250.0   24.0
# 2       hari   CompA  150.0   25.0
# 3      karim   CompB  340.0  250.0
# 4    vanitha   CompB    NaN    NaN
# 5  prasanthi   CompC  243.0   27.0
# 6      mouli   CompC  350.0   24.0
# 7        dev   CompA  250.0   24.0

# %%
df.head()
# Out:
#     Person Company  Sales    Age
# 0    tarak   CompA  250.0   23.0
# 1     deva   CompA  250.0   24.0
# 2     hari   CompA  150.0   25.0
# 3    karim   CompB  340.0  250.0
# 4  vanitha   CompB    NaN    NaN

# %%
df.tail()
# Out:
#       Person Company  Sales    Age
# 3      karim   CompB  340.0  250.0
# 4    vanitha   CompB    NaN    NaN
# 5  prasanthi   CompC  243.0   27.0
# 6      mouli   CompC  350.0   24.0
# 7        dev   CompA  250.0   24.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Person   8 non-null      object
#  1   Company  8 non-null      object
#  2   Sales    7 non-null      float64
#  3   Age      7 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 384.0+ bytes

# %%
df.shape
# Out:
# (8, 4)

# %%
df.shape[0]
# Out:
# 8

# %%
df.shape[1]
# Out:
# 4

# %%
df.describe().T
# Out:
#        count        mean        std    min    25%    50%    75%    max
# Sales    7.0  261.857143  67.286523  150.0  246.5  250.0  295.0  350.0
# Age      7.0   56.714286  85.240277   23.0   24.0   24.0   26.0  250.0

# %%
df.describe(include="object").T
# Out:
#         count unique    top freq
# Person      8      8  tarak    1
# Company     8      3  CompA    4

# %%
df.describe(include="all").T
# Out:
#         count unique    top freq        mean        std    min    25%    50%
# Person      8      8  tarak    1         NaN        NaN    NaN    NaN    NaN  \
# Company     8      3  CompA    4         NaN        NaN    NaN    NaN    NaN
# Sales     7.0    NaN    NaN  NaN  261.857143  67.286523  150.0  246.5  250.0
# Age       7.0    NaN    NaN  NaN   56.714286  85.240277   23.0   24.0   24.0
#
#            75%    max
# Person     NaN    NaN
# Company    NaN    NaN
# Sales    295.0  350.0
# Age       26.0  250.0

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Person Company  Sales    Age
# 0      tarak   CompA  250.0   23.0
# 1        dev   CompA  250.0   24.0
# 2       hari   CompA  150.0   25.0
# 3      karim   CompB  340.0  250.0
# 4    vanitha   CompB    NaN    NaN
# 5  prasanthi   CompC  243.0   27.0
# 6      mouli   CompC  350.0   24.0

# %%
df.isnull()
# Out:
#    Person  Company  Sales    Age
# 0   False    False  False  False
# 1   False    False  False  False
# 2   False    False  False  False
# 3   False    False  False  False
# 4   False    False   True   True
# 5   False    False  False  False
# 6   False    False  False  False

# %%
df.isnull().sum()
# Out:
# Person     0
# Company    0
# Sales      1
# Age        1
# dtype: int64

# %%
df["Sales"].fillna(df["Sales"].mean(),inplace=True)

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)

# %%
df
# Out:
#       Person Company       Sales    Age
# 0      tarak   CompA  250.000000   23.0
# 1        dev   CompA  250.000000   24.0
# 2       hari   CompA  150.000000   25.0
# 3      karim   CompB  340.000000  250.0
# 4    vanitha   CompB  263.833333   24.5
# 5  prasanthi   CompC  243.000000   27.0
# 6      mouli   CompC  350.000000   24.0

# %%
df["Age"].median()
# Out:
# 24.5

# %%
df["Age"].replace(250.0,df["Age"].median(),inplace=True)

# %%
df
# Out:
#       Person Company       Sales   Age
# 0      tarak   CompA  250.000000  23.0
# 1        dev   CompA  250.000000  24.0
# 2       hari   CompA  150.000000  25.0
# 3      karim   CompB  340.000000  24.5
# 4    vanitha   CompB  263.833333  24.5
# 5  prasanthi   CompC  243.000000  27.0
# 6      mouli   CompC  350.000000  24.0

# %%
#0--->rows 1-->column
df.dropna(axis=0,how="all")
df.dropna(axis="columns",how="any")
# Out:
#       Person Company       Sales   Age
# 0      tarak   CompA  250.000000  23.0
# 1        dev   CompA  250.000000  24.0
# 2       hari   CompA  150.000000  25.0
# 3      karim   CompB  340.000000  24.5
# 4    vanitha   CompB  263.833333  24.5
# 5  prasanthi   CompC  243.000000  27.0
# 6      mouli   CompC  350.000000  24.0

# %%
df.groupby("Company")["Sales"].sum().plot.bar();

# %%
df.groupby("Person")["Sales"].sum().plot.pie();
